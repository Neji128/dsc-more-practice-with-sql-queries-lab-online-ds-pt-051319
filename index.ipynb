# %% [markdown]
# # More Practice With SQL Queries - Lab
#
# ## Introduction
#
# In this lesson, we'll run through some practice questions to refresh our knowledge of SQL Queries!
#
# ## Objectives
#
# You will be able to:
#
# - Practice your SQL knowledge
#
# ## Getting Started
#
# As in previous labs, we'll make use of the `sqlite3` library as well as `pandas`. By combining them, we'll be able to write our queries as python strings, and make sure that the results are always returned as a pandas DataFrame.
#
# We'll start by loading both libraries and connecting to the database we'll be using for this lab, `data.sqlite`. You may remember this database from a previous lab. As a refresher, here's the ERD diagram for this database:
#
# <img src='images/Database-Schema.png'>
#
# In the cell below:
#
# * Import the necessary libraries `pandas` and `sqlite3`
# * Establish a connection to the database `data.sqlite`
# * Get the `cursor` from the connection and store it in the variable `c`.

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect('data.sqlite')
c = conn.cursor()

# %% [markdown]
# ## Basic Queries
#
# Now, let's review basic SQL queries. In the cell below:
#
# * Write a query that gets the first name, last name, phone number, address, and credit limit for all customers in California with a credit limit greater than 25000.00.

# %%
# For the first query, the boilerplate for getting 
#the query into a dataframe has been provided for you
c.execute("""SELECT contactFirstName, contactLastName, phone, addressLine1, creditLimit FROM customers""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#     contactFirstName  contactLastName               phone  \
# 0            Carine           Schmitt          40.32.2555
# 1               Jean             King          7025551838
# 2              Peter         Ferguson        03 9520 4555
# 3            Janine           Labrune          40.67.8555
# 4             Jonas        Bergulfsen          07-98 9555
# 5              Susan           Nelson          4155551450
# 6           Zbyszek   Piestrzeniewicz       (26) 642-7555
# 7             Roland           Keitel   +49 69 66 90 2555
# 8              Julie           Murphy          6505555787
# 9               Kwai              Lee          2125557818
# 10            Diego            Freyre      (91) 555 94 44
# 11        Christina          Berglund        0921-12 3555
# 12            Jytte          Petersen          31 12 3555
# 13             Mary           Saveley          78.32.5555
# 14              Eric        Natividad        +65 221 7555
# 15              Jeff            Young          2125557413
# 16            Kelvin            Leong          2155551555
# 17              Juri        Hashimoto          6505556809
# 18             Wendy        Victorino        +65 224 1555
# 19            Veysel           Oeztan       +47 2267 3215
# 20             Keith           Franco          2035557845
# 21           Isabel         de Castro        (1) 356-5555
# 22          Martine             Rancé          20.16.1555
# 23             Marie         Bertrand      (1) 42.34.2555
# 24             Jerry            Tseng          6175555555
# 25             Julie             King          2035552570
# 26              Mory          Kentary    +81 06 6342 5555
# 27           Michael            Frick          2125551500
# 28             Matti        Karttunen         90-224 8555
# 29            Rachel         Ashworth      (171) 555-1555
# ..               ...              ...                 ...
# 92         Maurizio            Moroni         0522-556555
# 93             Akiko        Shimamura     +81 3 3584 0555
# 94         Dominique          Perrier      (1) 47.55.6555
# 95             Rita            Müller         0711-555361
# 96             Sarah            McRoy         04 499 9555
# 97           Michael      Donnermeyer   +49 89 61 08 9555
# 98             Maria        Hernandez          2125558493
# 99        Alexander             Feuer         0342-555176
# 100              Dan            Lewis          2035554407
# 101           Martha          Larsson        0695-34 6555
# 102              Sue            Frick          4085553659
# 103          Roland            Mendel           7675-3555
# 104           Leslie           Murphy          2035559545
# 105               Yu             Choi          2125551957
# 106          Martín            Sommer      (91) 555 22 82
# 107            Sven           Ottlieb         0241-039123
# 108          Violeta          Benitez          5085552555
# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-1.png'>
#
# ## Aggregate Functions and GROUP BY
#
# Next, write a query that get sthe average credit limit per state.

# %%
c.execute("""SELECT state, AVG(creditLimit) FROM customers GROUP BY state""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#             state  AVG(creditLimit)
# 0                      61839.726027
# 1              BC      89950.000000
# 2              CA      83854.545455
# 3              CT      57350.000000
# 4        Co. Cork          0.000000
# 5   Isle of Wight      93900.000000
# 6              MA      70755.555556
# 7              NH     114200.000000
# 8              NJ      43000.000000
# 9             NSW     100550.000000
# 10             NV      71800.000000
# 11             NY      89966.666667
# 12          Osaka      81200.000000
# 13             PA      84766.666667
# 14       Pretoria          0.000000
# 15     Queensland      51600.000000
# 16         Québec      48700.000000
# 17          Tokyo      94400.000000
# 18       Victoria      88800.000000

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-2.png'>
#
# ## JOINs
#
# Now, write a query that uses JOIN statements to get the customer name, customer number, order number, status, and quantity ordered. Print only the head of this DataFrame.

# %%
c.execute("""SELECT customerName, customerNumber, 
            orderNumber, status, quantityOrdered 
            FROM customers JOIN orders USING(customerNumber) 
            JOIN orderdetails USING(orderNumber)""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#                       customerName  customerNumber orderNumber      status  \
# 0     Online Diecast Creations Co.             363       10100     Shipped
# 1     Online Diecast Creations Co.             363       10100     Shipped
# 2     Online Diecast Creations Co.             363       10100     Shipped
# 3     Online Diecast Creations Co.             363       10100     Shipped
# 4             Blauer See Auto, Co.             128       10101     Shipped
# 5             Blauer See Auto, Co.             128       10101     Shipped
# 6             Blauer See Auto, Co.             128       10101     Shipped
# 7             Blauer See Auto, Co.             128       10101     Shipped
# 8                  Vitachrome Inc.             181       10102     Shipped
# 9                  Vitachrome Inc.             181       10102     Shipped
# 10              Baane Mini Imports             121       10103     Shipped
# 11              Baane Mini Imports             121       10103     Shipped
# 12              Baane Mini Imports             121       10103     Shipped
# 13              Baane Mini Imports             121       10103     Shipped
# 14              Baane Mini Imports             121       10103     Shipped
# 15              Baane Mini Imports             121       10103     Shipped
# 16              Baane Mini Imports             121       10103     Shipped
# 17              Baane Mini Imports             121       10103     Shipped
# 18              Baane Mini Imports             121       10103     Shipped
# 19              Baane Mini Imports             121       10103     Shipped
# 20              Baane Mini Imports             121       10103     Shipped
# 21              Baane Mini Imports             121       10103     Shipped
# 22              Baane Mini Imports             121       10103     Shipped
# 23              Baane Mini Imports             121       10103     Shipped
# 24              Baane Mini Imports             121       10103     Shipped
# 25              Baane Mini Imports             121       10103     Shipped
# 26          Euro+ Shopping Channel             141       10104     Shipped
# 27          Euro+ Shopping Channel             141       10104     Shipped
# 28          Euro+ Shopping Channel             141       10104     Shipped
# 29          Euro+ Shopping Channel             141       10104     Shipped
# ...                            ...             ...         ...         ...
# 2966     Souveniers And Things Co.             282       10420  In Process
# 2967     Souveniers And Things Co.             282       10420  In Process
# 2968  Mini Gifts Distributors Ltd.             124       10421  In Process
# 2969  Mini Gifts Distributors Ltd.             124       10421  In Process
# 2970         Diecast Classics Inc.             157       10422  In Process
# 2971         Diecast Classics Inc.             157       10422  In Process
# 2972                    Petit Auto             314       10423  In Process
# 2973                    Petit Auto             314       10423  In Process
# 2974                    Petit Auto             314       10423  In Process
# 2975                    Petit Auto             314       10423  In Process
# 2976                    Petit Auto             314       10423  In Process
# 2977        Euro+ Shopping Channel             141       10424  In Process
# 2978        Euro+ Shopping Channel             141       10424  In Process
# 2979        Euro+ Shopping Channel             141       10424  In Process
# 2980        Euro+ Shopping Channel             141       10424  In Process
# 2981        Euro+ Shopping Channel             141       10424  In Process
# 2982        Euro+ Shopping Channel             141       10424  In Process
# 2983             La Rochelle Gifts             119       10425  In Process
# 2984             La Rochelle Gifts             119       10425  In Process
# 2985             La Rochelle Gifts             119       10425  In Process
# 2986             La Rochelle Gifts             119       10425  In Process
# 2987             La Rochelle Gifts             119       10425  In Process
# 2988             La Rochelle Gifts             119       10425  In Process
# 2989             La Rochelle Gifts             119       10425  In Process
# 2990             La Rochelle Gifts             119       10425  In Process
# 2991             La Rochelle Gifts             119       10425  In Process
# 2992             La Rochelle Gifts             119       10425  In Process
# 2993             La Rochelle Gifts             119       10425  In Process
# 2994             La Rochelle Gifts             119       10425  In Process
# 2995             La Rochelle Gifts             119       10425  In Process
#
#      quantityOrdered
# 0                 22
# 1                 30
# 2                 49
# 3                 50
# 4                 25
# 5                 26
# 6                 45
# 7                 46
# 8                 39
# 9                 41
# 10                22
# 11                25
# 12                25
# 13                26
# 14                27
# 15                27
# 16                31
# 17                35
# 18                35
# 19                36
# 20                36
# 21                41
# 22                42
# 23                42
# 24                45
# 25                46
# 26                23
# 27                24
# 28                26
# 29                29
# ...              ...
# 2966              60
# 2967              66
# 2968              35
# 2969              40
# 2970              25
# 2971              51
# 2972              10
# 2973              21
# 2974              21
# 2975              28
# 2976              31
# 2977              26
# 2978              44
# 2979              46
# 2980              49
# 2981              50
# 2982              54
# 2983              11
# 2984              18
# 2985              19
# 2986              28
# 2987              28
# 2988              31
# 2989              33
# 2990              38
# 2991              38
# 2992              38
# 2993              41
# 2994              49
# 2995              55
#
# [2996 rows x 5 columns]

# %% [markdown]
# #### Expected Output
#
# <img src='images/joins.png'>
#
# ## HAVING and ORDER BY
#
# Now, return the customerName, customrerNumber, productName, productCode and total number ordered for any product a customer has bought 10 or more of cumulatively. Sort the rows in descending order by the quantity ordered.
#
# **_Hint_**: For this one, you'll need to make use of HAVING, GROUP BY, and ORDER BY--make sure you get the order of them correct!

# %%
c.execute("""SELECT c.customerName, c.customerNumber, 
                   p.productName, od.productCode, sum(od.quantityOrdered) as TotalOrdered
                   
             FROM customers c JOIN orders o USING(customerNumber) 
                             JOIN orderdetails od USING(orderNumber)
                             JOIN products p USING(productcode)
             GROUP BY c.customerNumber, productCode
             HAVING SUM(od.quantityOrdered) >= 10
             ORDER BY TotalOrdered DESC""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df
# Out:
#                        customerName  customerNumber  \
# 0            Euro+ Shopping Channel             141
# 1            Euro+ Shopping Channel             141
# 2            Euro+ Shopping Channel             141
# 3            Euro+ Shopping Channel             141
# 4            Euro+ Shopping Channel             141
# 5      Mini Gifts Distributors Ltd.             124
# 6            Euro+ Shopping Channel             141
# 7            Euro+ Shopping Channel             141
# 8            Euro+ Shopping Channel             141
# 9            Euro+ Shopping Channel             141
# 10           Euro+ Shopping Channel             141
# 20                          1970 Triumph Spitfire    S18_4027           138
# 21                               1969 Ford Falcon    S12_3891           137
# 22                       Collectable Wooden Train    S18_3259           137
# 23                              1952 Citroen-15CV    S24_2887           135
# 24                     1970 Chevy Chevelle SS 454    S24_1046           133
# 25                        1982 Lamborghini Diablo    S24_2972           132
# 26                       1962 Volkswagen Microbus    S24_2300           131
# 27                      1969 Chevrolet Camaro Z28    S24_3191           129
# 28                                    The Titanic   S700_3505           126
# 29                           1969 Dodge Super Bee    S18_3278           126
# ...                                           ...         ...           ...
# 2501                    1957 Corvette Convertible    S18_4721            20
# 2502                            1982 Ducati 996 R    S32_2206            20
# 2503                  1939 Chevrolet Deluxe Coupe    S24_1937            20
# 2504                     1928 Ford Phaeton Deluxe    S32_4289            20
# 2505                    1937 Horch 930V Limousine    S24_3420            20
# 2506               1998 Chrysler Plymouth Prowler    S18_2238            20
# 2507                 1999 Indy 500 Monte Carlo SS    S18_2870            20
# 2508  1996 Peterbilt 379 Stake Bed with Outrigger    S32_3522            20
# 2509             1912 Ford Model T Delivery Wagon    S24_3151            20
# 2510                             Boeing X-32A JSF    S72_1253            20
# 2511                  1948 Porsche 356-A Roadster    S18_1889            20
# 2512                  1939 Chevrolet Deluxe Coupe    S24_1937            20
# 2513    1938 Cadillac V-16 Presidential Limousine    S24_2022            20
# 2514                        1936 Chrysler Airflow    S24_4258            20
# 2515                           2002 Yamaha YZR M1    S50_4713            20
# 2516                        1936 Chrysler Airflow    S24_4258            20
# 2517                        1926 Ford Fire Engine    S18_2432            19
# 2518             Diamond T620 Semi-Skirted Tanker    S50_1392            18
# 2519                     Corsair F4U ( Bird Cage)    S24_3949            18
# 2520                    1937 Horch 930V Limousine    S24_3420            18
# 2521                         1969 Dodge Super Bee    S18_3278            16
# 2522             1936 Mercedes Benz 500k Roadster    S24_3969            15
# 2523                      1982 Lamborghini Diablo    S24_2972            15
# 2524                               P-51-D Mustang    S18_2581            15
# 2525             1936 Mercedes Benz 500k Roadster    S24_3969            15
# 2526                    1969 Chevrolet Camaro Z28    S24_3191            13
# 2527                  1954 Greyhound Scenicruiser    S32_2509            11
# 2528                  American Airlines: B767-300   S700_1691            11
# 2529                  1913 Ford Model T Speedster    S18_2949            10
# 2530                        1961 Chevrolet Impala    S24_4620            10
#
# [2531 rows x 5 columns]

# %% [markdown]
# #### Expected Output
#
# <img src='images/having_order.png'>
#
# ## Subqueries
#
# Finally, get the first name, last name, employee number, and office code for employees from an office with less than 5 employees.

# %%
c.execute("""SELECT lastName, firstName, employeeNumber, officeCode
             FROM employees
             WHERE officeCode IN (SELECT officeCode
                                  FROM offices
                                  JOIN employees
                                  USING(officeCode)
                                  GROUP BY 1
                                  HAVING COUNT(employeeNumber) < 5)""")
df = pd.DataFrame(c.fetchall())
df.columns = [x[0] for x in c.description]
df.head()
# Out:
#     lastName firstName employeeNumber officeCode
# 0  Patterson   William           1088          6
# 1   Firrelli     Julie           1188          2
# 2  Patterson     Steve           1216          2
# 3      Tseng  Foon Yue           1286          3
# 4     Vanauf    George           1323          3

# %% [markdown]
# #### Expected Output
#
# <img src='images/expected-output-5.png'>
#
# # Summary
#
# In this lesson, we reviewed all the major concepts and keywords associated with SQL queries!
